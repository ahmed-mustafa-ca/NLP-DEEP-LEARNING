# %%
import pandas as pd

# %%
data = pd.DataFrame({"text_data" : [
    "Hello world!",
    "Python is amazing",
    "Text manipulation tutorials are on youtube",
    "Lets learn strings"
]})

# %%
data
# Out:
#                                     text_data
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text_data  4 non-null      object
# dtypes: object(1)
# memory usage: 164.0+ bytes

# %%
data["concatenated"] = data["text_data"] + " Concatenated!"

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                         concatenated
# 0                         Hello world! Concatenated!
# 1                    Python is amazing Concatenated!
# 2  Text manipulation tutorials are on youtube Con...
# 3                   Lets learn strings Concatenated!

# %%
data["lenght"] = data["text_data"].apply(len)

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                         concatenated  lenght
# 0                         Hello world! Concatenated!      12
# 1                    Python is amazing Concatenated!      17
# 2  Text manipulation tutorials are on youtube Con...      42
# 3                   Lets learn strings Concatenated!      18

# %%
data["Uppercase"] = data["text_data"].str.upper()

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                         concatenated  lenght  \
# 0                         Hello world! Concatenated!      12
# 1                    Python is amazing Concatenated!      17
# 2  Text manipulation tutorials are on youtube Con...      42
# 3                   Lets learn strings Concatenated!      18
#
#                                     Uppercase
# 0                                HELLO WORLD!
# 1                           PYTHON IS AMAZING
# 2  TEXT MANIPULATION TUTORIALS ARE ON YOUTUBE
# 3                          LETS LEARN STRINGS

# %%
data["Loercase"] = data["text_data"].str.lower()

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                         concatenated  lenght  \
# 0                         Hello world! Concatenated!      12
# 1                    Python is amazing Concatenated!      17
# 2  Text manipulation tutorials are on youtube Con...      42
# 3                   Lets learn strings Concatenated!      18
#
#                                     Uppercase  \
# 0                                HELLO WORLD!
# 1                           PYTHON IS AMAZING
# 2  TEXT MANIPULATION TUTORIALS ARE ON YOUTUBE
# 3                          LETS LEARN STRINGS
#
#                                      Loercase
# 0                                hello world!
# 1                           python is amazing
# ...

# %%
data = data[["text_data"]]

# %%
data
# Out:
#                                     text_data
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings

# %%
data["substring"] = data["text_data"].str[0.10]
# Out:
# C:\Users\Jamshaid Mustafa\AppData\Local\Temp\ipykernel_28024\3771826651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["substring"] = data["text_data"].str[0.10]

# %%
data
# Out:
#                                     text_data  substring
# 0                                Hello world!        NaN
# 1                           Python is amazing        NaN
# 2  Text manipulation tutorials are on youtube        NaN
# 3                          Lets learn strings        NaN

# %%
data["contains_python"] = data["text_data"].str.contains("Python")
# Out:
# C:\Users\Jamshaid Mustafa\AppData\Local\Temp\ipykernel_28024\3184425101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["contains_python"] = data["text_data"].str.contains("Python")

# %%
data
# Out:
#                                     text_data  substring  contains_python
# 0                                Hello world!        NaN            False
# 1                           Python is amazing        NaN             True
# 2  Text manipulation tutorials are on youtube        NaN            False
# 3                          Lets learn strings        NaN            False

# %%
data = data[["text_data"]]

# %%
data["Replace_text"] = data["text_data"].str.replace("learn","cover")
# Out:
# C:\Users\Jamshaid Mustafa\AppData\Local\Temp\ipykernel_28024\608870440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Replace_text"] = data["text_data"].str.replace("learn","cover")

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                  Replace_text
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets cover strings

# %%
data["text_data"][0].split()
# Out:
# ['Hello', 'world!']

# %%
data["word_count"] = data["text_data"].apply(lambda x : len(x.split()))

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                  Replace_text  word_count
# 0                                Hello world!           2
# 1                           Python is amazing           3
# 2  Text manipulation tutorials are on youtube           6
# 3                          Lets cover strings           3

# %%
data["unique_characters"] = data["text_data"].apply(lambda x : " ".join(set(x)))

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                  Replace_text  word_count  \
# 0                                Hello world!           2
# 1                           Python is amazing           3
# 2  Text manipulation tutorials are on youtube           6
# 3                          Lets cover strings           3
#
#                    unique_characters
# 0                    d r H o l e ! w
# 1          g i s   h z t o a P n m y
# 2  b x i s   u r t o p a n e l T m y
# 3              L g i s   r t a l e n

# %%
data["word_list"] = data["text_data"].str.split()

# %%
data
# Out:
#                                     text_data  \
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings
#
#                                  Replace_text  word_count  \
# 0                                Hello world!           2
# 1                           Python is amazing           3
# 2  Text manipulation tutorials are on youtube           6
# 3                          Lets cover strings           3
#
#                    unique_characters  \
# 0                    d r H o l e ! w
# 1          g i s   h z t o a P n m y
# 2  b x i s   u r t o p a n e l T m y
# 3              L g i s   r t a l e n
#
#                                            word_list
# 0                                    [Hello, world!]
# 1                              [Python, is, amazing]
# 2  [Text, manipulation, tutorials, are, on, youtube]
# ...

# %%
data = data[["text_data"]]

# %%
data
# Out:
#                                     text_data
# 0                                Hello world!
# 1                           Python is amazing
# 2  Text manipulation tutorials are on youtube
# 3                          Lets learn strings

# %%
data["substring_count"] = data["text_data"].str.count("o")
# Out:
# C:\Users\Jamshaid Mustafa\AppData\Local\Temp\ipykernel_28024\3581329175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["substring_count"] = data["text_data"].str.count("o")

# %%
data
# Out:
#                                     text_data  substring_count
# 0                                Hello world!                2
# 1                           Python is amazing                1
# 2  Text manipulation tutorials are on youtube                4
# 3                          Lets learn strings                0

# %%
data
# Out:
#                                     text_data  substring_count
# 0                                Hello world!                2
# 1                           Python is amazing                1
# 2  Text manipulation tutorials are on youtube                4
# 3                          Lets learn strings                0

# %%
data["reversed_text"] = data["text_data"].str[::-1]
# Out:
# C:\Users\Jamshaid Mustafa\AppData\Local\Temp\ipykernel_28024\2762022233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["reversed_text"] = data["text_data"].str[::-1]

# %%
data
# Out:
#                                     text_data  substring_count  \
# 0                                Hello world!                2
# 1                           Python is amazing                1
# 2  Text manipulation tutorials are on youtube                4
# 3                          Lets learn strings                0
#
#                                 reversed_text
# 0                                !dlrow olleH
# 1                           gnizama si nohtyP
# 2  ebutuoy no era slairotut noitalupinam txeT
# 3                          sgnirts nrael steL
