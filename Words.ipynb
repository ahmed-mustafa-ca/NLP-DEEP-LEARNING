# %%
import nltk
from sklearn.feature_extraction.text import CountVectorizer

# %%
sentences = "I want to visit london as soon as possible because i heard that london is a great place"

# %%
tokens = nltk.word_tokenize(sentences)

# %%
tokens
# Out:
# ['I',
#  'want',
#  'to',
#  'visit',
#  'london',
#  'as',
#  'soon',
#  'as',
#  'possible',
#  'because',
#  'i',
#  'heard',
#  'that',
#  'london',
#  'is',
#  'a',
#  'great',
#  'place']

# %%
vectorizer = CountVectorizer()

# %%
bow_representation = vectorizer.fit_transform([sentences]).toarray()

# %%
bow_representation
# Out:
# array([[2, 1, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 1]])
